# %% [markdown]
# #### 분해하려는 원본 행렬 R을 P와 Q로 분해한 후에 다시 P와 t(Q)의 내적으로 예측 행렬의 만드는 예제

# %%
import numpy as np

# %%
#원본 행렬 R생성, 분해행렬 P와 Q초기화, 잠재 요인 차원 K는 3으로 설정
R= np.array([[4,np.NaN, np.NaN,2 ,np.NaN],[np.NaN,5,np.NaN,3,1],[np.NaN,np.NaN,3,4,4],[5,2,1,2,np.NaN]])

num_users, num_items=R.shape
K=3

# %%
# P와 Q행렬의 크기를 지정하고 정규분포를 가진 임의의 값으로 입력
np.random.seed(1)
P=np.random.normal(scale=1./K, size=(num_users,K))
Q=np.random.normal(scale=1./K, size=(num_items,K))

# %%
# 실제 R행렬과 예측 행렬의 오차를 구하는 get_rmse()함수

from sklearn.metrics import mean_squared_error

# %%
def get_rmse(R,P,Q,non_zeros):
    error=0
    #두개의 분해된 행렬 P와 T(Q)의 내적으로 예측 행렬 생성
    full_pred_matrix= np.dot(P,Q.T)
    
    #실제 R행렬에서 널이 아닌 값의 위치 인덱스 추출해 실제 R행렬과 예측 행렬의 RMSE값 추출
    x_non_zero_ind= [non_zero[0] for non_zero in non_zeros]
    y_non_zero_ind= [non_zero[1] for non_zero in non_zeros]
    R_non_zeros=R[x_non_zero_ind, y_non_zero_ind]
    full_pred_matrix_non_zeros=full_pred_matrix[x_non_zero_ind, y_non_zero_ind]
    mse=mean_squared_error(R_non_zeros, full_pred_matrix_non_zeros)
    rmse=np.sqrt(mse)
    
    return rmse

# %%
# R>0인 행의 위치, 열의 위치, 값을 non-zeros 리스트에 저장
non_zeros = [(i,j,R[i,j]) for i in range(num_users) for j in range(num_items) if R[i,j]>0]

steps=1000
learning_rate=0.01
r_lambda=0.01

#SGD 기법으로 P와 Q매트릭스를 계속 업데이트
for step in range(steps):
    for i,j,r in non_zeros:
        #실제 값과 예측값의 차이인 오류값 구함
        eij=r-np.dot(P[i,:],Q[j,:].T)
        # 규제를 반영한 SGD업데이트 공식 적용
        P[i,:]=P[i,:]+learning_rate*(eij*Q[j,:]-r_lambda*P[i,:])
        Q[j,:]=Q[j,:]+learning_rate*(eij*P[i,:]-r_lambda*Q[j,:])
        rmse=get_rmse(R,P,Q,non_zeros)
        if (step%50)==0:
            print('### iteration step: ', step, "rmse: ",rmse)
# Out:
# ### iteration step:  0 rmse:  3.257685974919492
# ### iteration step:  0 rmse:  3.2567784112905804
# ### iteration step:  0 rmse:  3.2503556288140967
# ### iteration step:  0 rmse:  3.248564885598423
# ### iteration step:  0 rmse:  3.2487420072644557
# ### iteration step:  0 rmse:  3.2474782606248875
# ### iteration step:  0 rmse:  3.2456461223335706
# ### iteration step:  0 rmse:  3.2438156312541464
# ### iteration step:  0 rmse:  3.2385009318957363
# ### iteration step:  0 rmse:  3.2366485436771972
# ### iteration step:  0 rmse:  3.2367673519475613
# ### iteration step:  0 rmse:  3.2353964232171952
# ### iteration step:  50 rmse:  0.5021726731206282
# ### iteration step:  50 rmse:  0.501958220155996
# ### iteration step:  50 rmse:  0.5008855357324867
# ### iteration step:  50 rmse:  0.5006882396215355
# ### iteration step:  50 rmse:  0.5007896401798277
# ### iteration step:  50 rmse:  0.500138053484773
# ### iteration step:  50 rmse:  0.5002489493156104
# ### iteration step:  50 rmse:  0.499774261611162
# ### iteration step:  50 rmse:  0.49181626573778714
# ### iteration step:  50 rmse:  0.490977202808275
# ### iteration step:  50 rmse:  0.490569183359231
# ### iteration step:  50 rmse:  0.4895175823385149
# ### iteration step:  100 rmse:  0.17216999669168997
# ### iteration step:  100 rmse:  0.17194053262163472
# ### iteration step:  100 rmse:  0.17189818096006318
# ### iteration step:  100 rmse:  0.17147082746667863
# ### iteration step:  100 rmse:  0.1714899629348335
# ### iteration step:  100 rmse:  0.17144590774531118
# ### iteration step:  100 rmse:  0.17102918725448413
# ### iteration step:  100 rmse:  0.17107602071558384
# ### iteration step:  100 rmse:  0.1703888309386653
# ### iteration step:  100 rmse:  0.17028861463409775
# ### iteration step:  100 rmse:  0.17001248334233537
# ### iteration step:  100 rmse:  0.16949342934563913
# ### iteration step:  150 rmse:  0.08736373263174688
# ### iteration step:  150 rmse:  0.08736911071348
# ### iteration step:  150 rmse:  0.0873656482702048
# ### iteration step:  150 rmse:  0.08708838927473522
# ### iteration step:  150 rmse:  0.08712485464276751
# ### iteration step:  150 rmse:  0.0871536111745264
# ### iteration step:  150 rmse:  0.08683405201673045
# ### iteration step:  150 rmse:  0.08687555728327934
# ### iteration step:  150 rmse:  0.08652278535868194
# ### iteration step:  150 rmse:  0.08653249365549336
# ### iteration step:  150 rmse:  0.08651978728350435
# ### iteration step:  150 rmse:  0.08636953278050478
# ### iteration step:  200 rmse:  0.05287450161173965
# ### iteration step:  200 rmse:  0.05295062110568685
# ### iteration step:  200 rmse:  0.052944493856910864
# ### iteration step:  200 rmse:  0.052721605579602815
# ### iteration step:  200 rmse:  0.05277137134366596
# ### iteration step:  200 rmse:  0.0528251596998573
# ### iteration step:  200 rmse:  0.05255517531249293
# ### iteration step:  200 rmse:  0.05257936443001503
# ### iteration step:  200 rmse:  0.052310495815853224
# ### iteration step:  200 rmse:  0.05233016351696835
# ### iteration step:  200 rmse:  0.05233435641694317
# ### iteration step:  200 rmse:  0.0524220366765247
# ### iteration step:  250 rmse:  0.036265894757408844
# ### iteration step:  250 rmse:  0.03636480182927093
# ### iteration step:  250 rmse:  0.03634216941352802
# ### iteration step:  250 rmse:  0.03615261613930572
# ### iteration step:  250 rmse:  0.03621666030087059
# ### iteration step:  250 rmse:  0.03627724410642409
# ### iteration step:  250 rmse:  0.036030450225963746
# ### iteration step:  250 rmse:  0.036039157162333114
# ### iteration step:  250 rmse:  0.03578697545417676
# ### iteration step:  250 rmse:  0.03581816614475386
# ### iteration step:  250 rmse:  0.035817719528355565
# ### iteration step:  250 rmse:  0.03602906955868924
# ### iteration step:  300 rmse:  0.02760191699034384
# ### iteration step:  300 rmse:  0.02770691823281592
# ### iteration step:  300 rmse:  0.027661227229345216
# ### iteration step:  300 rmse:  0.02749673590512133
# ### iteration step:  300 rmse:  0.02757463777186481
# ### iteration step:  300 rmse:  0.027632468618257695
# ### iteration step:  300 rmse:  0.027400046044840098
# ### iteration step:  300 rmse:  0.027397963189344083
# ### iteration step:  300 rmse:  0.027135927430260227
# ### iteration step:  300 rmse:  0.027185421585608584
# ### iteration step:  300 rmse:  0.027195802707861892
# ### iteration step:  300 rmse:  0.02746648148445232
# ### iteration step:  350 rmse:  0.02301655839295339
# ### iteration step:  350 rmse:  0.02312136875355765
# ### iteration step:  350 rmse:  0.023052664960367775
# ### iteration step:  350 rmse:  0.022908952514036702
# ### iteration step:  350 rmse:  0.02299807436437278
# ### iteration step:  350 rmse:  0.023047989774138616
# ### iteration step:  350 rmse:  0.022827610061256026
# ### iteration step:  350 rmse:  0.022818751537130415
# ### iteration step:  350 rmse:  0.0225400255805377
# ### iteration step:  350 rmse:  0.022609012924462428
# ### iteration step:  350 rmse:  0.022637311024612142
# ### iteration step:  350 rmse:  0.02293152744697502
# ### iteration step:  400 rmse:  0.020592725923693992
# ### iteration step:  400 rmse:  0.020695208824862966
# ### iteration step:  400 rmse:  0.020607837453276025
# ### iteration step:  400 rmse:  0.020481048821203055
# ### iteration step:  400 rmse:  0.020577829771002136
# ### iteration step:  400 rmse:  0.020618598588431264
# ### iteration step:  400 rmse:  0.020408963160227677
# ### iteration step:  400 rmse:  0.020396207629870704
# ### iteration step:  400 rmse:  0.020103401147472718
# ### iteration step:  400 rmse:  0.020188540015009502
# ### iteration step:  400 rmse:  0.020233322170600948
# ### iteration step:  400 rmse:  0.02053225393731638
# ### iteration step:  450 rmse:  0.019292305052442726
# ### iteration step:  450 rmse:  0.019392251249987058
# ### iteration step:  450 rmse:  0.019291483658645216
# ### iteration step:  450 rmse:  0.01917759680243536
# ### iteration step:  450 rmse:  0.019279083158630934
# ### iteration step:  450 rmse:  0.019311924096032516
# ### iteration step:  450 rmse:  0.01911103377113689
# ### iteration step:  450 rmse:  0.019096161154297416
# ### iteration step:  450 rmse:  0.018793976130309906
# ### iteration step:  450 rmse:  0.01889074298815217
# ### iteration step:  450 rmse:  0.018947731348898697
# ### iteration step:  450 rmse:  0.01924345594141933
# ### iteration step:  500 rmse:  0.018567641468389767
# ### iteration step:  500 rmse:  0.018665547099932754
# ### iteration step:  500 rmse:  0.018555672492480687
# ### iteration step:  500 rmse:  0.018451122399654303
# ### iteration step:  500 rmse:  0.01855541285604667
# ### iteration step:  500 rmse:  0.018582290651051634
# ### iteration step:  500 rmse:  0.01838784660586922
# ### iteration step:  500 rmse:  0.018371828777752744
# ### iteration step:  500 rmse:  0.018063955035791168
# ### iteration step:  500 rmse:  0.0181685933076601
# ### iteration step:  500 rmse:  0.018233848326408085
# ### iteration step:  500 rmse:  0.018524251222309242
# ### iteration step:  550 rmse:  0.018140626984146552
# ### iteration step:  550 rmse:  0.018237065208651728
# ### iteration step:  550 rmse:  0.018121044464481127
# ### iteration step:  550 rmse:  0.01802310999937813
# ### iteration step:  550 rmse:  0.018129119029429618
# ### iteration step:  550 rmse:  0.018151815936830365
# ### iteration step:  550 rmse:  0.017961825001460888
# ### iteration step:  550 rmse:  0.017945152263330554
# ### iteration step:  550 rmse:  0.017633888608404796
# ### iteration step:  550 rmse:  0.01774379959642639
# ### iteration step:  550 rmse:  0.017814512069723582
# ### iteration step:  550 rmse:  0.01809982449659415
# ### iteration step:  600 rmse:  0.017871473219624852
# ### iteration step:  600 rmse:  0.01796687862041019
# ### iteration step:  600 rmse:  0.01784661818680947
# ### iteration step:  600 rmse:  0.01775340203040729
# ### iteration step:  600 rmse:  0.017860535098775155
# ### iteration step:  600 rmse:  0.017880386661372368
# ### iteration step:  600 rmse:  0.01769337654928536
# ### iteration step:  600 rmse:  0.01767628491593127
# ### iteration step:  600 rmse:  0.01736294523937459
# ### iteration step:  600 rmse:  0.017476460527105952
# ### iteration step:  600 rmse:  0.017550807213748836
# ### iteration step:  600 rmse:  0.01783190040098341
# ### iteration step:  650 rmse:  0.017688805473706062
# ### iteration step:  650 rmse:  0.017783452690297585
# ### iteration step:  650 rmse:  0.017660148270656918
# ### iteration step:  650 rmse:  0.017570391087207878
# ### iteration step:  650 rmse:  0.017678322693851722
# ### iteration step:  650 rmse:  0.017696246297398445
# ### iteration step:  650 rmse:  0.017511223609377315
# ### iteration step:  650 rmse:  0.01749382232855782
# ### iteration step:  650 rmse:  0.017179136101675475
# ### iteration step:  650 rmse:  0.0172952133634194
# ### iteration step:  650 rmse:  0.017372050760651854
# ### iteration step:  650 rmse:  0.017649789728815122
# ### iteration step:  700 rmse:  0.017555101198078682
# ### iteration step:  700 rmse:  0.017649143609319656
# ### iteration step:  700 rmse:  0.017523540412945206
# ### iteration step:  700 rmse:  0.017436427070629982
# ### iteration step:  700 rmse:  0.017544975614524738
# ### iteration step:  700 rmse:  0.01756157470111827
# ### iteration step:  700 rmse:  0.01737790434150743
# ### iteration step:  700 rmse:  0.01736024112338667
# ### iteration step:  700 rmse:  0.017044610975541313
# ### iteration step:  700 rmse:  0.0171626030032795
# ### iteration step:  700 rmse:  0.017241220557064573
# ### iteration step:  700 rmse:  0.01751628771810187
# ### iteration step:  750 rmse:  0.017449987602527993
# ### iteration step:  750 rmse:  0.017543501254184066
# ### iteration step:  750 rmse:  0.017416065377202115
# ### iteration step:  750 rmse:  0.01733107403709735
# ### iteration step:  750 rmse:  0.017440135376924234
# ### iteration step:  750 rmse:  0.01745579848980261
# ### iteration step:  750 rmse:  0.01727308809955314
# ### iteration step:  750 rmse:  0.01725518141053467
# ### iteration step:  750 rmse:  0.01693883057479288
# ### iteration step:  750 rmse:  0.01705833388076598
# ### iteration step:  750 rmse:  0.017138289243980233
# ### iteration step:  750 rmse:  0.017411176676572892
# ### iteration step:  800 rmse:  0.017362071664119873
# ### iteration step:  800 rmse:  0.017455088896876834
# ### iteration step:  800 rmse:  0.017326114750806754
# ### iteration step:  800 rmse:  0.01724291193664959
# ### iteration step:  800 rmse:  0.017352424360288936
# ### iteration step:  800 rmse:  0.017367399603326374
# ### iteration step:  800 rmse:  0.017185412160792647
# ### iteration step:  800 rmse:  0.01716726708527195
# ### iteration step:  800 rmse:  0.01685032113105378
# ### iteration step:  800 rmse:  0.016971081549962932
# ### iteration step:  800 rmse:  0.01705209711732439
# ### iteration step:  800 rmse:  0.017323144852643777
# ### iteration step:  850 rmse:  0.01728482163677906
# ### iteration step:  850 rmse:  0.017377353224542397
# ### iteration step:  850 rmse:  0.01724702972439033
# ### iteration step:  850 rmse:  0.01716540115226413
# ### iteration step:  850 rmse:  0.017275326641940363
# ### iteration step:  850 rmse:  0.017289772677429583
# ### iteration step:  850 rmse:  0.017108366822764846
# ### iteration step:  850 rmse:  0.017089982822969314
# ### iteration step:  850 rmse:  0.01677251476731554
# ### iteration step:  850 rmse:  0.016894369559692774
# ### iteration step:  850 rmse:  0.016976268781208132
# ### iteration step:  850 rmse:  0.017245706628693135
# ### iteration step:  900 rmse:  0.017214415156008737
# ### iteration step:  900 rmse:  0.017306463595805295
# ### iteration step:  900 rmse:  0.01717491473584887
# ### iteration step:  900 rmse:  0.0170947209373952
# ### iteration step:  900 rmse:  0.017205034945585722
# ### iteration step:  900 rmse:  0.017219054357072053
# ### iteration step:  900 rmse:  0.017038145836450493
# ### iteration step:  900 rmse:  0.017019520493198288
# ### iteration step:  900 rmse:  0.016701575727274133
# ### iteration step:  900 rmse:  0.016824418215372332
# ### iteration step:  900 rmse:  0.0169070866069194
# ### iteration step:  900 rmse:  0.017175067917642978
# ### iteration step:  950 rmse:  0.017148576017577116
# ### iteration step:  950 rmse:  0.017240142866187393
# ### iteration step:  950 rmse:  0.017107452586997956
# ### iteration step:  950 rmse:  0.01702860084104876
# ### iteration step:  950 rmse:  0.017139286603027392
# ### iteration step:  950 rmse:  0.017152947173087046
# ### iteration step:  950 rmse:  0.016972484796651907
# ### iteration step:  950 rmse:  0.016953615539436234
# ### iteration step:  950 rmse:  0.016635225549397645
# ### iteration step:  950 rmse:  0.016758983510145292
# ### iteration step:  950 rmse:  0.016842344790616928
# ### iteration step:  950 rmse:  0.01710897100956365

# %%
pred_matrix =np.dot(P,Q.T)
print('예측행렬:\n', np.round(pred_matrix,3))
# Out:
# 예측행렬:
#  [[3.99  0.669 1.378 2.003 1.794]
#  [6.716 4.978 0.929 2.98  1.003]
#  [7.173 0.45  2.987 3.976 3.986]
#  [4.967 2.005 1.008 2.02  1.184]]
